# %% [markdown]
# # Telco Customer Churn Exploration
# Load the Kaggle Telco Customer Churn dataset and run quick EDA.

# %%
import pandas as pd
df = pd.read_csv('data/raw/telco_churn_raw.csv')
df.head()
